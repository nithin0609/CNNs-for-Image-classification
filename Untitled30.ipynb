# %%
import numpy as np
import matplotlib.pyplot as plt
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Conv2D, Dropout, Flatten, MaxPooling2D
from tensorflow.keras.optimizers import SGD
from sklearn.utils import shuffle
from sklearn.metrics import confusion_matrix, accuracy_score
import seaborn as sns

from tensorflow.keras.datasets import cifar10
(x_train, y_train), (x_test, y_test) = cifar10.load_data()

x_data = np.concatenate([x_train, x_test])
y_data = np.concatenate([y_train, y_test])
x_data, y_data = shuffle(x_data, y_data, random_state=42)

x_train, x_val, x_test = x_data[:35000], x_data[35000:50000], x_data[50000:]
y_train, y_val, y_test = y_data[:35000], y_data[35000:50000], y_data[50000:]

x_train = x_train.astype('float32') / 255.0
x_val = x_val.astype('float32') / 255.0
x_test = x_test.astype('float32') / 255.0

VGGNet = Sequential()
VGGNet.add(Conv2D(32, (3, 3), activation='relu', padding='same', input_shape=(32, 32, 3)))
VGGNet.add(Conv2D(32, (3, 3), activation='relu', padding='same'))
VGGNet.add(MaxPooling2D((2, 2)))
VGGNet.add(Conv2D(64, (3, 3), activation='relu', padding='same'))
VGGNet.add(Conv2D(64, (3, 3), activation='relu', padding='same'))
VGGNet.add(MaxPooling2D((2, 2)))
VGGNet.add(Flatten())
VGGNet.add(Dense(512, activation='relu'))
VGGNet.add(Dropout(0.5))
VGGNet.add(Dense(10, activation='softmax'))

VGGNet.compile(optimizer=SGD(lr=0.001, momentum=0.9), loss='sparse_categorical_crossentropy', metrics=['accuracy'])

VGGNet.summary()

history2 = VGGNet.fit(x_train, y_train, epochs=50, validation_data=(x_val, y_val), verbose=1)

plt.plot(history2.history['accuracy'])
plt.plot(history2.history['val_accuracy'])
plt.title("Accuracy by VGGNet on CIFAR-10 Data")
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

plt.plot(history2.history['loss'])
plt.plot(history2.history['val_loss'])
plt.title("Loss by VGGNet on CIFAR-10 Data")
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

y_predictions2 = VGGNet.predict(x_test)
y_predictions2 = np.argmax(y_predictions2, axis=1)

classes_name = ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']

plt.figure(figsize=(10, 8))
sns.heatmap(confusion_matrix(y_test, y_predictions2), annot=True, fmt='d', cmap='Blues', xticklabels=classes_name, yticklabels=classes_name)
plt.xlabel('Predicted labels')
plt.ylabel('True labels')
plt.title('Confusion matrix of VGGNet Model')
plt.show()

print("Test accuracy by VGGNet:", accuracy_score(y_test, y_predictions2))
# Out:
# C:\Users\nithin\anaconda3\lib\site-packages\scipy\__init__.py:138: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.24.4)
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion} is required for this version of "
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.SGD.
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 32, 32, 32)        896
#
#  conv2d_1 (Conv2D)           (None, 32, 32, 32)        9248
#
#  max_pooling2d (MaxPooling2  (None, 16, 16, 32)        0
#  D)
#
#  conv2d_2 (Conv2D)           (None, 16, 16, 64)        18496
#
#  conv2d_3 (Conv2D)           (None, 16, 16, 64)        36928
#
#  max_pooling2d_1 (MaxPoolin  (None, 8, 8, 64)          0
#  g2D)
#
#  flatten (Flatten)           (None, 4096)              0
#
#  dense (Dense)               (None, 512)               2097664
#
#  dropout (Dropout)           (None, 512)               0
#
#  dense_1 (Dense)             (None, 10)                5130
#
# =================================================================
# Total params: 2168362 (8.27 MB)
# Trainable params: 2168362 (8.27 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1
# 1094/1094 [==============================] - 104s 95ms/step - loss: 0.3126 - accuracy: 0.9057 - val_loss: 1.3543 - val_accuracy: 0.7075
# Epoch 43/50
# 1094/1094 [==============================] - 103s 94ms/step - loss: 0.3064 - accuracy: 0.9093 - val_loss: 1.3771 - val_accuracy: 0.7031
# Epoch 44/50
# 1094/1094 [==============================] - 103s 94ms/step - loss: 0.3116 - accuracy: 0.9069 - val_loss: 1.3060 - val_accuracy: 0.6898
# Epoch 45/50
# 1094/1094 [==============================] - 103s 94ms/step - loss: 0.3292 - accuracy: 0.9027 - val_loss: 1.3691 - val_accuracy: 0.7011
# Epoch 46/50
# 1094/1094 [==============================] - 103s 95ms/step - loss: 0.3109 - accuracy: 0.9091 - val_loss: 1.4586 - val_accuracy: 0.6944
# Epoch 47/50
# 1094/1094 [==============================] - 103s 94ms/step - loss: 0.3345 - accuracy: 0.9038 - val_loss: 1.5774 - val_accuracy: 0.7043
# Epoch 48/50
# 1094/1094 [==============================] - 103s 94ms/step - loss: 0.3520 - accuracy: 0.8961 - val_loss: 1.5354 - val_accuracy: 0.6992
# Epoch 49/50
# 1094/1094 [==============================] - 103s 94ms/step - loss: 0.3425 - accuracy: 0.8999 - val_loss: 1.4931 - val_accuracy: 0.6937
# Epoch 50/50
# 1094/1094 [==============================] - 103s 94ms/step - loss: 0.3315 - accuracy: 0.9047 - val_loss: 1.6650 - val_accuracy: 0.6843
# 313/313 [==============================] - 5s 16ms/step
# Test accuracy by VGGNet: 0.6756

# %%
from tensorflow import keras
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, accuracy_score

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Conv2D, Dropout, Flatten, MaxPooling2D
from tensorflow.keras.optimizers import SGD, Adam

AlexNet = Sequential()
AlexNet.add(Conv2D(filters=96, input_shape=(224,224,3), kernel_size=(11,11), strides=(4,4), padding='valid'))
AlexNet.add(MaxPooling2D(pool_size=(3,3), strides=(2,2), padding='valid'))
AlexNet.add(Conv2D(filters=256, kernel_size=(5,5), strides=(1,1), padding='valid'))
AlexNet.add(MaxPooling2D(pool_size=(3,3), strides=(2,2), padding='valid'))
AlexNet.add(Flatten())
AlexNet.add(Dense(4096))
AlexNet.add(Dropout(0.5))
AlexNet.add(Dense(4096))
AlexNet.add(Dropout(0.5))
AlexNet.add(Dense(1000, activation='softmax'))
AlexNet.compile(optimizer=Adam(learning_rate=0.001), loss='categorical_crossentropy', metrics=['accuracy'])

AlexNet = Sequential()
AlexNet.add(Conv2D(filters=16,kernel_size=(3,3),strides=(4,4),input_shape=(32,32,3), activation='relu'))
AlexNet.add(MaxPooling2D(pool_size=(2,2),strides=(2,2)))
AlexNet.add(Conv2D(60,(5,5),padding='same',activation='relu'))
AlexNet.add(MaxPooling2D(pool_size=(2,2),strides=(2,2)))
AlexNet.add(Conv2D(60,(3,3),padding='same',activation='relu'))
AlexNet.add(Conv2D(30,(3,3),padding='same',activation='relu'))
AlexNet.add(Conv2D(20,(3,3),padding='same',activation='relu'))
AlexNet.add(MaxPooling2D(pool_size=(2,2),strides=(2,2)))
AlexNet.add(Flatten())
AlexNet.add(Dense(200, activation='relu'))
AlexNet.add(Dropout(0.1))
AlexNet.add(Dense(200, activation='relu'))
AlexNet.add(Dropout(0.1))
AlexNet.add(Dense(10,activation='softmax'))
AlexNet.compile(optimizer='SGD', loss=keras.losses.sparse_categorical_crossentropy, metrics=['accuracy'])
AlexNet.summary()

from tensorflow.keras.datasets import cifar10
(x_train_full, y_train_full), (x_test, y_test) = cifar10.load_data()

x_train = x_train_full[:35000]
y_train = y_train_full[:35000]
x_val = x_train_full[35000:50000]
y_val = y_train_full[35000:50000]

history1 = AlexNet.fit(x_train, y_train, epochs=100, validation_data=(x_val, y_val), verbose=1)

plt.plot(history1.history['accuracy'])
plt.plot(history1.history['val_accuracy'])
plt.title("Accuracy by AlexNet on CIFAR-10 Data")
plt.ylabel('Accuracy')
plt.xlabel('Epochs')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

plt.plot(history1.history['loss'])
plt.plot(history1.history['val_loss'])
plt.title('Loss by AlexNet on CIFAR-10 Data')
plt.ylabel('Loss')
plt.xlabel('Epochs')
plt.legend(['Train', 'Validation'])
plt.show()

y_predictions1 = AlexNet.predict(x_test)
y_predictions1 = np.argmax(y_predictions1, axis=1)

confusion_matrix(y_test, y_predictions1)

plt.figure(figsize=(7, 6))
plt.title('Confusion matrix of AlexNet Model')
plt.imshow(confusion_matrix(y_test, y_predictions1))
plt.colorbar()
plt.show()

print("Test accuracy by AlexNet:", accuracy_score(y_test, y_predictions1))
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_6 (Conv2D)           (None, 8, 8, 16)          448
#
#  max_pooling2d_4 (MaxPoolin  (None, 4, 4, 16)          0
#  g2D)
#
#  conv2d_7 (Conv2D)           (None, 4, 4, 60)          24060
#
#  max_pooling2d_5 (MaxPoolin  (None, 2, 2, 60)          0
#  g2D)
#
#  conv2d_8 (Conv2D)           (None, 2, 2, 60)          32460
#
#  conv2d_9 (Conv2D)           (None, 2, 2, 30)          16230
#
#  conv2d_10 (Conv2D)          (None, 2, 2, 20)          5420
#
#  max_pooling2d_6 (MaxPoolin  (None, 1, 1, 20)          0
#  g2D)
#
#  flatten_2 (Flatten)         (None, 20)                0
#
#  dense_5 (Dense)             (None, 200)               4200
#
#  dropout_3 (Dropout)         (None, 200)               0
#
#  dense_6 (Dense)             (None, 200)               40200
#
#  dropout_4 (Dropout)         (None, 200)               0
#
#  dense_7 (Dense)             (None, 10)                2010
#
# =================================================================
# Total params: 125028 (488.39 KB)
# Trainable params: 125028 (488.39 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/100
# 1094/1094 [==============================] - 14s 12ms/step - loss: 1.9968 - accuracy: 0.2574 - val_loss: 1.9971 - val_accuracy: 0.2890
# Epoch 2/100
# 1094/1094 [==============================] - 11s 10ms/step - loss: 1.7061 - accuracy: 0.3780 - val_loss: 1.6107 - val_accuracy: 0.4148
# Epoch 3/100
# 1094/1094 [==============================] - 12s 11ms/step - loss: 1.5885 - accuracy: 0.4309 - val_loss: 1.5593 - val_accuracy: 0.4392
# Epoch 4/100
# 1094/1094 [==============================] - 10s 9ms/step - loss: 1.5084 - accuracy: 0.4587 - val_loss: 1.5528 - val_accuracy: 0.4538
# Epoch 5/100
# 1094/1094 [==============================] - 12s 11ms/step - loss: 1.4447 - accuracy: 0.4847 - val_loss: 1.5208 - val_accuracy: 0.4611
# Epoch 6/100
# 1094/1094 [==============================] - 11s 10ms/step - loss: 1.4008 - accuracy: 0.5005 - val_loss: 1.4141 - val_accuracy: 0.4923
# Epoch 7/100
# 1094/1094 [==============================] - 12s 11ms/step - loss: 1.3518 - accuracy: 0.5182 - val_loss: 1.4311 - val_accuracy: 0.4849
# Epoch 8/100
# 1094/1094 [==============================] - 12s 11ms/step - loss: 1.3155 - accuracy: 0.5327 - val_loss: 1.3942 - val_accuracy: 0.5025
# Epoch 9/100
# 1094/1094 [==============================] - 12s 11ms/step - loss:
# Epoch 84/100
# 1094/1094 [==============================] - 11s 10ms/step - loss: 0.3049 - accuracy: 0.8937 - val_loss: 3.0912 - val_accuracy: 0.4965
# Epoch 85/100
# 1094/1094 [==============================] - 10s 9ms/step - loss: 0.3026 - accuracy: 0.8974 - val_loss: 2.9242 - val_accuracy: 0.5049
# Epoch 86/100
# 1094/1094 [==============================] - 10s 9ms/step - loss: 0.3020 - accuracy: 0.8974 - val_loss: 2.9653 - val_accuracy: 0.4949
# Epoch 87/100
# 1094/1094 [==============================] - 10s 9ms/step - loss: 0.3002 - accuracy: 0.8967 - val_loss: 3.0851 - val_accuracy: 0.4963
# Epoch 88/100
# 1094/1094 [==============================] - 10s 9ms/step - loss: 0.2865 - accuracy: 0.9009 - val_loss: 3.2107 - val_accuracy: 0.4923
# Epoch 89/100
# 1094/1094 [==============================] - 10s 9ms/step - loss: 0.2939 - accuracy: 0.8994 - val_loss: 2.9789 - val_accuracy: 0.4996
# Epoch 90/100
# 1094/1094 [==============================] - 10s 9ms/step - loss: 0.2909 - accuracy: 0.9013 - val_loss: 3.1065 - val_accuracy: 0.4991
# Epoch 91/100
# 1094/1094 [==============================] - 10s 9ms/step - loss: 0.2871 - accuracy: 0.9024 - val_loss: 3.0368 - val_accuracy: 0.4965
# Epoch 92/100
# 1094/1094 [==============================] - 10s 9ms/step - loss: 0.2723 - accuracy: 0.9054 - val_loss: 3.0567 - val_accuracy: 0.5018
# Epoch 93/100
# 1094/1094 [==============================] - 11s 10ms/step - loss: 0.2697 - accuracy: 0.9090 - val_loss: 3.2990 - val_accuracy: 0.4915
# Epoch 94/100
# 1094/1094 [==============================] - 10s 9ms/step - loss: 0.2816 - accuracy: 0.9048 - val_loss: 3.0610 - val_accuracy: 0.4988
# Epoch 95/100
# 1094/1094 [==============================] - 12s 11ms/step - loss: 0.2669 - accuracy: 0.9098 - val_loss: 3.1691 - val_accuracy: 0.4986
# Epoch 96/100
# 1094/1094 [==============================] - 13s 11ms/step - loss: 0.2458 - accuracy: 0.9162 - val_loss: 3.2235 - val_accuracy: 0.4915
# Epoch 97/100
# 1094/1094 [==============================] - 12s 11ms/step - loss: 0.2807 - accuracy: 0.9046 - val_loss: 2.9394 - val_accuracy: 0.4965
# Epoch 98/100
# 1094/1094 [==============================] - 13s 12ms/step - loss: 0.2557 - accuracy: 0.9139 - val_loss: 3.1750 - val_accuracy: 0.5001
# Epoch 99/100
# 1094/1094 [==============================] - 11s 10ms/step - loss: 0.2437 - accuracy: 0.9171 - val_loss: 3.3299 - val_accuracy: 0.4959
# Epoch 100/100
# 1094/1094 [==============================] - 12s 11ms/step - loss: 0.2499 - accuracy: 0.9157 - val_loss: 3.5612 - val_accuracy: 0.4967
# 313/313 [==============================] - 1s 3ms/step
# Test accuracy by AlexNet: 0.4939

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras
from sklearn.metrics import ConfusionMatrixDisplay, classification_report, confusion_matrix
import warnings
import seaborn as sns

warnings.filterwarnings("ignore")

(x_train_full, y_train_full), (x_test, y_test)  = keras.datasets.cifar10.load_data()

x_train = x_train_full[:35000]
y_train = y_train_full[:35000]
x_val = x_train_full[35000:50000]
y_val = y_train_full[35000:50000]

y_train = y_train.reshape(-1,)
y_val = y_val.reshape(-1,)
y_test = y_test.reshape(-1,)

x_train = x_train / 255.0
x_val = x_val / 255.0
x_test = x_test / 255.0

classes = ["airplane","automobile","bird","cat","deer","dog","frog","horse","ship","truck"]

lenet = keras.models.Sequential([
    keras.layers.Conv2D(6, kernel_size=5, strides=1,  activation='relu', input_shape=(32,32,3), padding='same'),
    keras.layers.AveragePooling2D(),
    keras.layers.Conv2D(16, kernel_size=5, strides=1, activation='relu', padding='valid'),
    keras.layers.AveragePooling2D(),
    keras.layers.Conv2D(120, kernel_size=5, strides=1, activation='relu', padding='valid'),
    keras.layers.Flatten(),
    keras.layers.Dense(84, activation='relu'),
    keras.layers.Dense(10, activation='softmax')
])

lenet.compile(optimizer='adam', loss=keras.losses.sparse_categorical_crossentropy, metrics=['accuracy'])

hist = lenet.fit(x_train, y_train, epochs=100, validation_data=(x_val, y_val),verbose=1)

plt.plot(hist.history['accuracy'])
plt.plot(hist.history['val_accuracy'])
plt.title("Accuracy by LeNet on CIFAR-10 Data")
plt.ylabel('Accuracy')
plt.xlabel('Epochs')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

plt.plot(hist.history['loss'])
plt.plot(hist.history['val_loss'])
plt.title('Loss by LeNet on CIFAR-10 Data')
plt.ylabel('Loss')
plt.xlabel('Epochs')
plt.legend(['Train', 'Validation'])
plt.show()

y_predictions= lenet.predict(x_test)
y_predictions= np.argmax(y_predictions, axis=1)

plt.figure(figsize=(7, 6))
plt.title('Confusion matrix')
plt.imshow(confusion_matrix(y_test, y_predictions))
plt.xticks(np.arange(10), classes, rotation=45)
plt.yticks(np.arange(10), classes)
plt.colorbar()
plt.show()

print("Test accuracy:", accuracy_score(y_test, y_predictions))

L = 8
W = 8
fig, axes = plt.subplots(L, W, figsize = (20,20))
axes = axes.ravel()

for i in np.arange(0, L * W):  
    axes[i].imshow(x_test[i])
    axes[i].set_title("Predicted = {}\n Actual  = {}".format(classes[y_predictions[i]], classes[y_test[i]]))
    axes[i].axis('off')
# Out:
# Epoch 1/100
# 1094/1094 [==============================] - 18s 15ms/step - loss: 1.7162 - accuracy: 0.3735 - val_loss: 1.5031 - val_accuracy: 0.4546
# Epoch 2/100
# 1094/1094 [==============================] - 16s 15ms/step - loss: 1.4258 - accuracy: 0.4874 - val_loss: 1.3705 - val_accuracy: 0.5107
# Epoch 3/100
# 1094/1094 [==============================] - 16s 15ms/step - loss: 1.3016 - accuracy: 0.5336 - val_loss: 1.3077 - val_accuracy: 0.5317
# Epoch 4/100
# 1094/1094 [==============================] - 16s 15ms/step - loss: 1.2127 - accuracy: 0.5655 - val_loss: 1.2454 - val_accuracy: 0.5599
# Epoch 5/100
# 1094/1094 [==============================] - 16s 14ms/step - loss: 1.1421 - accuracy: 0.5931 - val_loss: 1.2264 - val_accuracy: 0.5652
# Epoch 6/100
# 1094/1094 [==============================] - 16s 14ms/step - loss: 1.0791 - accuracy: 0.6166 - val_loss: 1.1605 - val_accuracy: 0.5933
# Epoch 7/100
# 1094/1094 [==============================] - 16s 15ms/step - loss: 1.0168 - accuracy: 0.6405 - val_loss: 1.1715 - val_accuracy: 0.5902
# Epoch 8/100
# 1094/1094 [==============================] - 16s 15ms/step - loss: 0.9679 - accuracy: 0.6574 - val_loss: 1.1973 - val_accuracy: 0.5839
# Epoch 9/100
# 1094/1094 [==============================] - 16s 14ms/step - loss: 0.9185 - accuracy: 0.6727 - val_loss: 1.1508 - val_accuracy: 0.5972
# Epoch 10/100
# Epoch 89/100
# 1094/1094 [==============================] - 16s 15ms/step - loss: 0.0943 - accuracy: 0.9701 - val_loss: 5.4536 - val_accuracy: 0.5701
# Epoch 90/100
# 1094/1094 [==============================] - 16s 15ms/step - loss: 0.1065 - accuracy: 0.9666 - val_loss: 5.4232 - val_accuracy: 0.5603
# Epoch 91/100
# 1094/1094 [==============================] - 16s 15ms/step - loss: 0.0817 - accuracy: 0.9728 - val_loss: 5.3365 - val_accuracy: 0.5677
# Epoch 92/100
# 1094/1094 [==============================] - 16s 15ms/step - loss: 0.1034 - accuracy: 0.9680 - val_loss: 5.4199 - val_accuracy: 0.5619
# Epoch 93/100
# 1094/1094 [==============================] - 16s 15ms/step - loss: 0.1097 - accuracy: 0.9651 - val_loss: 5.3291 - val_accuracy: 0.5666
# Epoch 94/100
# 1094/1094 [==============================] - 16s 15ms/step - loss: 0.0858 - accuracy: 0.9729 - val_loss: 5.3769 - val_accuracy: 0.5650
# Epoch 95/100
# 1094/1094 [==============================] - 16s 15ms/step - loss: 0.0950 - accuracy: 0.9696 - val_loss: 5.4316 - val_accuracy: 0.5653
# Epoch 96/100
# 1094/1094 [==============================] - 16s 15ms/step - loss: 0.0944 - accuracy: 0.9707 - val_loss: 5.5760 - val_accuracy: 0.5603
# Epoch 97/100
# 1094/1094 [==============================] - 16s 15ms/step - loss: 0.0978 - accuracy: 0.9691 - val_loss: 5.4866 - val_accuracy: 0.5721
# Epoch 98/100
# 1094/1094 [==============================] - 16s 15ms/step - loss: 0.0776 - accuracy: 0.9751 - val_loss: 5.8405 - val_accuracy: 0.5617
# Epoch 99/100
# 1094/1094 [==============================] - 16s 15ms/step - loss: 0.0941 - accuracy: 0.9693 - val_loss: 5.4364 - val_accuracy: 0.5675
# Epoch 100/100
# 1094/1094 [==============================] - 16s 15ms/step - loss: 0.0753 - accuracy: 0.9754 - val_loss: 5.7035 - val_accuracy: 0.5699
# 313/313 [==============================] - 1s 5ms/step
# Test accuracy: 0.5631

# %%
 import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from tensorflow import keras
import seaborn as sns 

# Load the CIFAR-10 dataset
(x, y), (x_test, y_test)  = keras.datasets.cifar10.load_data()

# Normalize the datasets
x = x / 255.0
x_test = x_test / 255.0

# Split the data into training, validation, and testing datasets
x_train, x_val = x[:35000], x[35000:50000]
y_train, y_val = y[:35000], y[35000:50000]

# Check the class distribution in each dataset
classes_name = ['Airplane', 'Automobile', 'Bird', 'Cat', 'Deer', 'Dog', 'Frog', 'Horse', 'Ship', 'Truck']

# Plotting class distribution in the training set
plt.figure(figsize=(8,6))
classes, counts = np.unique(y_train, return_counts=True)
sns.barplot(classes_name, counts)
plt.title('Class distribution in training set')
plt.tight_layout()
plt.show()

# Plotting class distribution in the validation set
plt.figure(figsize=(8,6))
classes, counts = np.unique(y_val, return_counts=True)
sns.barplot(classes_name, counts)
plt.title('Class distribution in validation set')
plt.tight_layout()
plt.show()

# Plotting class distribution in the testing set
plt.figure(figsize=(8,6))
classes, counts = np.unique(y_test, return_counts=True)
sns.barplot(classes_name, counts)
plt.title('Class distribution in testing set')
plt.tight_layout()
plt.show()
